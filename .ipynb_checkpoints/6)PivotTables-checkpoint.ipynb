# %%
import numpy as np 
import pandas as pd

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)

df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    234     26   John  January      Q1
# 1  2023-01-02       B   West    250     67   Mary  January      Q1
# 2  2023-01-03       C  North    859     57    Bob  January      Q1
# 3  2023-01-04       D  South    433     84  Alice  January      Q1
# 4  2023-01-05       A   East    882     27   John  January      Q1
# 5  2023-01-06       B   West    201     66   Mary  January      Q1
# 6  2023-01-07       C  North    397     64    Bob  January      Q1
# 7  2023-01-08       D  South    462     51  Alice  January      Q1
# 8  2023-01-09       A   East    349     45   John  January      Q1
# 9  2023-01-10       B   West    524     37   Mary  January      Q1
# 10 2023-01-11       C  North    649     90    Bob  January      Q1
# 11 2023-01-12       D  South    323     27  Alice  January      Q1
# 12 2023-01-13       A   East    287     75   John  January      Q1
# 13 2023-01-14       B   West    417     44   Mary  January      Q1
# 14 2023-01-15       C  North    778     15    Bob  January      Q1
# 15 2023-01-16       D  South    260     36  Alice  January      Q1
# 16 2023-01-17       A   East    165     23   John  January      Q1
# 17 2023-01-18       B   West    669     91   Mary  January      Q1
# 18 2023-01-19       C  North    155     92    Bob  January      Q1
# 19 2023-01-20       D  South    462     84  Alice  January      Q1

# %%
pd.pivot_table(df,values="Sales", index= "Region", columns="Product", aggfunc='median')
# Out:
# Product      A      B      C      D
# Region
# East     287.0    NaN    NaN    NaN
# North      NaN    NaN  649.0    NaN
# South      NaN    NaN    NaN  433.0
# West       NaN  417.0    NaN    NaN

# %%
pivot2 = pd.pivot_table(df, values=['Sales', 'Units'], index='Region', columns='Product')
pivot2
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     383.4    NaN    NaN    NaN  39.2   NaN   NaN   NaN
# North      NaN    NaN  567.6    NaN   NaN   NaN  63.6   NaN
# South      NaN    NaN    NaN  388.0   NaN   NaN   NaN  56.4
# West       NaN  412.2    NaN    NaN   NaN  61.0   NaN   NaN

# %%
pd.crosstab(df['Region'],df['Product'])
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0
